# %%
import json # for saving a file

# %%
ingrDict = {'fish sauce': "fish_sauce",
            'garam masala': "garam_masala",
            'cinnamon stick': "cinnamon_stick",
            'cardamom pods': "cardamom_pods",
            'fenugreek seeds': "fenugreek_seeds",
            'light cream': "light_cream",
            'heavy cream': "heavy_cream",
            'tomato puree': "tomato_puree",
            'chili powder': "chili_powder",
            'chili paste': "chili_paste",
            'sea salt': "salt",
            #'salt': "salt",
            'shrimp paste': "shrimp paste",
            'cilantro stems': "cilantro",
            'cilantro': "cilantro",
            'cayenne pepper': " ",
            #'sugar': "sugar",
            'brown sugar': "brown_sugar",
            'soy sauce': "soy_sauce",
            'coconut milk': "coconut_milk",
            'kaffir lime': "lime_leaves",
            'kaffir lime leaves': "lime_leaves",
            'lemongrass': "lemongrass",
            #'jalapenos': "jalapenos",
            #'clove': "clove",
            #'ginger': "ginger",
            'fresh ginger': "ginger",
            'grated fresh ginger': "ginger",
            'grated ginger': "ginger",
            'ground paprika': "paprika",
            'ground turmeric': "turmeric",
            'ground cumin': "cumin",
            'ground coriander': "coriander",
            'ground black pepper': "black_pepper",
            'black pepper': "black_pepper",
            'lime juice': "lime_juice",
            'fish sauce': "fish_sauce",
            'thai basil': "thai_basil",
            #'galangal': "galangal",
            #'garlic': "garlic",
            #'shallots': "shallots",
            'red onions': "onion",
            #'onion': 'onion',
            'chillies': "chilli",
            'chilies': "chilli",
            'chicken stock': 'chicken_stock',
            'powdered turmeric': 'turmeric',
            'yellow onion': 'onion',
            'turmeric root': ' ',
            'shrimp paste': 'shrimp_paste',
            'dried red chilli': 'chilli',
            "red chile powder": "chilli",
            "green chiles": "chilli",
            'tom yam hot and sour paste': 'tomyam_paste',
            "papaya paste": "papaya_paste",
            "garlic paste": "garlic_paste",
            "6 1/2": "6.50",
            "1 1/2": "1.50",
            "1 1/4": "1.25",
            "1/2": "0.50",
            "1/3": "0.33",
            "1/4": "0.25",
            "2/3": "0.67",
            "3/4": "0.75",
            "1/8": "0.125",
            'green cardamom pods': 'cardamom_pods',
            'kosher salt': 'kosher_salt',
            "basil leaves": "basil_leaves",
            "coconut cream": "coconut_cream",
            "Greek yogurt": "yogurt",
            "fennel seeds": "fennel_seeds",
            "poppy seeds": "poppy_seeds",
            "curry paste": "curry_paste",
            "cumin seeds": "cumin",
            "curry powder": "curry_powder"
           }

with open('ingrDict.txt', 'w') as f:
    f.write(json.dumps(ingrDict))

# %%
len(ingrDict)
# Out:
# 64

# %%
ingrTagDict = {"fish_sauce": 'INGR',
               "garam_masala": 'INGR',
               #"cinnamon_stick": 'INGR',
               "cardamom_pods": 'INGR',
               "fenugreek_seeds": 'INGR',
               "light_cream": 'INGR',
               "heavy_cream": 'INGR',
               #"tomato_puree": 'INGR',
               "chili_powder": 'INGR',
               "chili_paste": 'INGR',
               #"salt": 'INGR',
               "shrimp paste": 'INGR',
               #"cilantro": 'INGR',
               "cayenne_pepper": 'INGR',
               "sugar": 'INGR',
               "brown_sugar": 'INGR',
               "soy_sauce": 'INGR',
               #"coconut_milk": 'INGR',
               #"lime_leaves": 'INGR',
               "lemongrass": 'INGR',
               #"jalapenos": 'INGR',
               #"clove": 'INGR',
               "ginger": 'INGR',
               "paprika": 'INGR',
               "turmeric": 'INGR',
               "cumin": 'INGR',
               "coriander": 'INGR',
               "black_pepper": 'INGR',
               "lime_juice": 'INGR',
               "fish_sauce": 'INGR',
               "thai_basil": 'INGR',
               "galangal": 'INGR',
               'garlic': "INGR",
               'shallots': "INGR",
               'onion': "INGR",
               'chilli': 'INGR',
               'yogurt': 'INGR',
               'garlic': 'INGR',
               'chicken_stock': 'INGR',
               'shrimp_paste' : 'INGR',
               'tomyam_paste': 'INGR',
               'butter': 'INGR',
               'kosher_salt': 'INGR',
               #'basil_leaves': 'INGR',
               'coconut_cream': 'INGR',
               "papaya_paste": "INGR",
               "garlic_paste": "INGR",
               "mint": "INGR",
               #"ghee ": "INGR",
               "fennel_seeds": "INGR",
               "poppy_seeds": "INGR",
               "mayonnaise": "INGR",
               "curry_paste": "INGR",
               "curry_powder": "INGR",
               "ketchup": "INGR",
               "mustard": "INGR",
               "nutmeg": "INGR"
           }

with open('ingrTagDict.txt', 'w') as f:
    f.write(json.dumps(ingrTagDict))

# %%
len(ingrTagDict)
# Out:
# 45

# %%
unitTagDict = {
    "can": 'UNIT',
    "cups": 'UNIT',
    "cup": 'UNIT',
    "teaspoons": 'UNIT',
    "teaspoon": 'UNIT',
    "tablespoons": 'UNIT',
    "tablespoon": 'UNIT',
    "pinches": 'UNIT',
    "pinch": 'UNIT',
    "sticks": 'UNIT',
    "stick": 'UNIT',
    "dozen": 'UNIT',
    "sheets": 'UNIT',
    "pounds": 'UNIT',
    "pound": 'UNIT',
    "bunch": 'UNIT',
    "stalk": 'UNIT',
    "stalks": 'UNIT',
    #"ounces": 'UNIT',
    #"ounce": 'UNIT',
    "cloves": 'UNIT'
}

with open('unitTagDict.txt', 'w') as f:
    f.write(json.dumps(unitTagDict))

# %%
cardTagDict = {
    'one': 'CARD',
    'two': 'CARD',
    'three': 'CARD',
    'four': 'CARD',
    'five': 'CARD',
    'six': 'CARD',
    'seven': 'CARD',
    'eight': 'CARD',
    'nine': 'CARD',
    'ten': 'CARD',
    '50': 'CARD',
    '49': 'CARD',
    '48': 'CARD',
    '47': 'CARD',
    '46': 'CARD',
    '45': 'CARD',
    '44': 'CARD',
    '43': 'CARD',
    '42': 'CARD',
    '41': 'CARD',
    '40': 'CARD',
    '39': 'CARD',
    '38': 'CARD',
    '37': 'CARD',
    '36': 'CARD',
    '35': 'CARD',
    '34': 'CARD',
    '33': 'CARD',
    '32': 'CARD',
    '31': 'CARD',
    '30': 'CARD',
    '29': 'CARD',
    '28': 'CARD',
    '27': 'CARD',
    '26': 'CARD',
    '25': 'CARD',
    '24': 'CARD',
    '23': 'CARD',
    '22': 'CARD',
    '21': 'CARD',
    '20': 'CARD',
    '19': 'CARD',
    '18': 'CARD',
    '17': 'CARD',
    '16': 'CARD',
    '15': 'CARD',
    '14': 'CARD',
    '13': 'CARD',
    '12': 'CARD',
    '11': 'CARD',
    '10': 'CARD',
    '9': 'CARD',
    '8': 'CARD',
    '7': 'CARD',
    "6.50": 'CARD',
    '6': 'CARD',
    "5.50": 'CARD',
    '5': 'CARD',
    "4.50": 'CARD',
    '4': 'CARD',
    "3.50": 'CARD',
    '3': 'CARD',
    "2.50": 'CARD',
    '2': 'CARD',
    "1.25": 'CARD',  
    "1.50": 'CARD',               
    '1': 'CARD',
    "0.50": 'CARD',
    "0.33": 'CARD',
    "0.25": 'CARD',
    "0.67": 'CARD',
    "0.75": 'CARD',
    "0.125": 'CARD'
}

with open('cardTagDict.txt', 'w') as f:
    f.write(json.dumps(cardTagDict))

# %%
# tiny_amount_of_ = tao_
# small_amount_of_ = sao_
# medium_amount_of_ = mao_
# lot_of_ = lo_
unitConvDict = {
    "0.125 teaspoon": "tao_",
    "0.25 teaspoon" : "tao_",
    "0.33 teaspoon" : "tao_",
    "0.50 teaspoon" : "sao_",
    "0.75 teaspoon" : "sao_",
    "1 teaspoon"    : "mao_",
    "1.25 teaspoons": "mao_",
    "1.50 teaspoons": "mao_",
    "1.75 teaspoons": "mao_",
    "2 teaspoons"   : "lo_",
    "3 teaspoons"   : "lo_",
    "4 teaspoons"   : "lo_",
    "5 teaspoons"   : "lo_",
    "6 teaspoons"   : "lo_",
    "1 tablespoon"  : "lo_",
    "1 tablespoons" : "lo_",
    "1.50 tablespoon" : "lo_",
    "1.50 tablespoons" : "lo_",
    "2 tablespoons" : "lo_",
    "3 tablespoons" : "lo_",
    "4 tablespoons" : "lo_",
    "5 tablespoons" : "lo_",
    "6 tablespoons" : "lo_",
    "0.25 cup": "sao_",
    "0.33 cup": "sao_",
    "0.50 cup": "sao_",
    "0.75 cup": "sao_",
    "1 cup": "mao_",
    "1.25 cups": "mao_",
    "1.25 cup": "mao_",
    "1.50 cups": "mao_",
    "2 cups": "lo_",
    "3 cups": "lo_",
    "3.50 cups": "lo_",
    "4 cups": "lo_",
    "5 cups": "lo_",
    "6 cups": "lo_",
    "6.50 cups": "lo_",
    "1 clove": "sao_",
    "2 cloves" : "sao_",
    "4 cloves" : "sao_",
    "10 cloves": "mao_",
    "1 pinch" : "tao_",
    "1 stalk" : "mao_",
    "0.25 pound": "sao_"
}

with open('unitConvDict.txt', 'w') as f:
    f.write(json.dumps(unitConvDict))
